# %%
# %load_ext tikzmagic
# Out:
# The tikzmagic extension is already loaded. To reload it, use:
#   %reload_ext tikzmagic

# %%
# %%tikz -l snakes --save qiqj_2_qiqj.png
# \draw[thick] node[below]{i} (0, 0) -- (1, 1) ;
# \draw[thick] (1, 1) -- (0, 2);
# \draw[thick] (3, 1) -- (4, 0) node[below]{j};
# \draw[thick] (3, 1) -- (4, 2);
# \draw[thick,snake=coil,segment length=5pt] (1, 1) -- (3, 1);

# %%
# %%tikz -l patterns
# \draw[pattern color=red,pattern=north east lines]  (0,0) circle (1cm) node[below] {$P_{el}^a$};
# \draw[pattern color=blue,pattern=north west lines] (1.5,0) circle (1cm) node [below] {$P_{inel}^a$};

# %%
# %%tikz -po "thick,fill opacity=0.5"
#   \filldraw[fill=red]   (0:1cm)    circle (12mm);
#   \filldraw[fill=green] (120:1cm)  circle (12mm);
#   \filldraw[fill=blue]  (-120:1cm) circle (12mm);

# %%
# %%tikz -po "thick,fill opacity=0.5" --save prob_total.png
# \filldraw[fill=red] (0:1cm) circle (12mm) node [below] {$P_{el}^a$};
# \filldraw[fill=blue] (180:1cm) circle (12mm) node [below] {$P_{inel}^a$};

# %%
# %%tikz --save clvisc_bulkinfo.png
# \draw (0, 0) node[inner sep=0] {\includegraphics[width=4cm]{ed_clvisc.png}};
# \draw[blue] (0.5, 0.5) rectangle (0.8, 0.8);
# \draw (4, 1) node {T, temperature};
# \draw (4, 0) node {$u^{\mu}$, fluid velocity};
# \draw [red,->] (0.65, 0.65) -- (2.5, 1);
# \draw [red,->] (0.65, 0.65) -- (2.5, 0);

# %%
# %%tikz
#
# \draw [->] (-1, 0) -- (3, 0) node [below] {x};
# \draw [->] (0, -1) -- (0, 3) node [left] {y};
# \draw [thick, fill=black] (0, 0) -- (30:2cm) circle (0.1cm) node [above] {P};
# \draw [thick, fill=blue!30] (0, 0) -- (1, 0) arc (0:30:1cm) node [right] {$\alpha$} circle;

# %%
# %%tikz
# \path (0, 0) coordinate (origin);
# \path (0:1cm) coordinate (P1);
# \path (1*72:1cm) coordinate (P2);
# \path (2*72:1cm) coordinate (P3);
# \path (3*72:1cm) coordinate (P4);
# \path (4*72:1cm) coordinate (P5);
#
# \draw [thick] (P1) -- (P2) -- (P3) -- (P4) -- (P5) -- cycle;
# \draw (origin) -- (P1) (origin) -- (P2)  (origin) -- (P3)  (origin) -- (P4)  (origin) -- (P5);

# %%
# %%tikz -l positioning
#
# \draw [fill=red] (0, 0) ellipse (2cm and 1cm);
# \draw [fill=white] (0, 0) ellipse (1cm and 0.5cm);
# \draw [fill=blue] (0, 0) ellipse (0.5cm and 0.25cm);

# %%
# %%tikz --scale 3
#
# \draw (0, 0) circle (1cm);
# \draw [dashed, fill=black] (0, 0) -- (30:1cm) circle (0.4mm) node [right] {P};
# \draw [red, thick] (30:1cm) arc (30:120:1cm);
# \draw [dashed] (0, 0) -- (120:1cm);
# \draw [->, thick] (0, 0) -- (0:1.5cm);
# \draw [->, thick] (0:0.5cm) arc (0:30:0.5cm)  node [midway, left] {$\alpha$};
# \draw [->, thick] (0:0.7cm) arc (0:120:0.7cm) node [midway, below] {$\beta$} ;

# %%
# %%tikz --scale 2
# \tikzstyle{every node}=[draw,shape=circle];
# \path (0,0) node  (v0) {$v_0$};
# \path (0:1cm) node  (v1) {$v_1$};
# \path (72:1cm) node (v2) {$v_2$};
# \path (2*72:1cm) node  (v3) {$v_3$};
# \path (3*72:1cm) node  (v4) {$v_4$};
# \path (4*72:1cm) node (v5) {$v_5$};
#
# \draw (v0) -- (v1) (v0) -- (v2) (v0) -- (v3) (v0) -- (v4) (v0) -- (v5);

# %%
# %%tikz --scale 2
#
# \draw (0,0) circle (1cm);
# \begin{scope}
# \clip (0, 0) circle (1cm);
# \fill [black] (0, 1) rectangle (-1, -1);
# \end{scope}
#
# \fill (90:0.5cm) circle (0.5cm);
# \fill [white] (270:0.5cm) circle (0.5cm);
# \fill [white] (90:0.5cm) circle (0.1cm);
# \fill [black] (270:0.5cm) circle (0.1cm);

# %%
# %%tikz --l positioning --scale 5 -po "fill opacity=0.8" --save anti_kt_cone.png
# \path (72:0.8cm) coordinate (pti);
# \path (50:1.0cm) coordinate (ptj);
#
# \draw [thick] (0, 0) -- (60:1.2cm);
# \draw [-] (0, 0) -- (45:1.24cm);
# \draw [-] (0, 0) -- (75:1.24cm);
# \draw [rotate=60, fill=blue!30] (0:1.2cm) ellipse (0.1cm and 0.32cm);
# \draw [thick,->] (60:1.2cm) -- (60:1.5cm) node (axis) [right] {jet axis};
# \draw [dashed, red] (60:1.2cm) -- (45:1.24cm) node [midway, right] {R};
#
# \draw [->]  (0, 0) -- (15:0.5cm);
# \draw [->]  (0, 0) -- (101:0.3cm);
# \draw [->]  (0, 0) -- (ptj)  node [right] (j) {j};
# \draw [->]  (0, 0) -- (pti)  node [right] (i) {i};

# %%
# %%tikz -l positioning -l snakes --scale 5 -po "fill opacity=0.8" --save multiple_scattering.png
# \path (72:0.8cm) coordinate (pti);
# \path (50:1.0cm) coordinate (ptj);
#
# \draw [thick] (0, 0) -- (60:1.2cm);
# \draw [-] (0, 0) -- (45:1.24cm);
# \draw [-] (0, 0) -- (75:1.24cm);
# \draw [rotate=60, fill=blue!30] (0:1.2cm) ellipse (0.1cm and 0.32cm);
# \draw [thick,->] (60:1.2cm) -- (60:1.5cm) node (axis) [right] {jet axis};
# \draw [dashed, red] (60:1.2cm) -- (45:1.24cm) node [midway, right] {R};
# \draw [->]  (0, 0) -- (ptj);
# \draw [->]  (0, 0) -- (pti);
# \draw[thick,snake=coil,segment length=5pt] (45:0.3cm) -- (0:0.3*1.414cm) node [right] {$\Delta p_{T1}$};
# \draw[thick,snake=coil,segment length=5pt] (45:0.6cm) -- (15:0.6*1.414cm) node [right] {$\Delta p_{T2}$};
# \draw[thick,snake=coil,segment length=5pt] (45:0.9cm) -- (30:0.9*1.414cm) node [right] {$\Delta p_{T\alpha}$};
# \draw[thick] (30:0.9cm) node [right] {...};
